# %%
import pandas as pd

# %%
wind_farms_victoria = pd.read_csv("../data/processed/victorian-wind-farms-with-ERA5_coordinates.csv")
wind_farms_victoria
# Out:
#                              Asset                    Main Owner  \
# 0                          Hepburn   Hepburn Community Wind Park
# 1                        Chepstowe                      BayWa re
# 2                          Maroona                      BayWa re
# 3                     Timboon West                   Epic Energy
# 4                           Yawong                   Epic Energy
# 5                         Ferguson                      BayWa re
# 6                        Wonthaggi                          EDCL
# 7                       Codrington                 Pacific Hydro
# 8                     Mortons Lane               CGN Wind Energy
# 9                  Coonooer Bridge                       Windlab
# 10                           Toora           Transfield Holdings
# 11               Cape Nelson North                 Pacific Hydro
# 12          Cape Sir William Grant                 Pacific Hydro
# ...
